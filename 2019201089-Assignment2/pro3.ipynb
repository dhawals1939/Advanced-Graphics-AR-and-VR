# %%
# !pip install pyglm
path = '/content/drive/My Drive/Colab Notebooks/Advanced-Graphics-AR-and-VR/2019201089-Assignment2'
import os
from google.colab.patches import cv2_imshow
import cv2
os.chdir(path)

# %%
# !cat problem_3.py
# Out:
# import math
# import sys
# import time
#
# from tqdm import tqdm
#
# from camera import camera
# from hittable import hit_record, hittable
# from hittable_list import hittable_list
# from sphere import sphere
# from box import box
#
# from cornell_box import cornell_box
# from material import *
# from aarect import *
#
#
# def write_color(file, color: glm.vec3, spp=1):
#     if file:
#         r, g, b = color.x, color.y, color.z
#
#         scale = 1 / spp
#         r = glm.sqrt(scale * r)
#         g = glm.sqrt(scale * g)
#         b = glm.sqrt(scale * b)
#
#         file.write('%d %d %d\n' % (256 * clamp(r, 0, .999),
#                                    256 * clamp(g, 0, .999),
#                                    256 * clamp(b, 0, .999)))
#
#
# def ray_color(r: ray, background: glm.vec3, world: hittable, depth: int) -> glm.vec3:
#     rec = hit_record()
#
#     if depth <= 0:
#         return glm.vec3(0, 0, 0)
#
#     if world.hit(r, 0.001, math.inf, rec):
# ...

# %%
# !python problem_3.py /content/sample_data/result_3.ppm 200 100
# Out:
# loading::  19% 43/225 [15:03<54:52, 18.09s/it]Traceback (most recent call last):
#   File "problem_3.py", line 105, in <module>
#   File "problem_3.py", line 44, in ray_color
#     return emitted + attenuation * ray_color(scattered, background, world, depth - 1)
#   File "problem_3.py", line 44, in ray_color
#     return emitted + attenuation * ray_color(scattered, background, world, depth - 1)
#   File "problem_3.py", line 44, in ray_color
#     return emitted + attenuation * ray_color(scattered, background, world, depth - 1)
#   [Previous line repeated 3 more times]
#   File "problem_3.py", line 38, in ray_color
#     if world.hit(r, 0.001, math.inf, rec):
#   File "/content/drive/My Drive/Colab Notebooks/Advanced-Graphics-AR-and-VR/2019201089-Assignment2/hittable_list.py", line 24, in hit
#     if obj.hit(r, t_min, closest_so_far, temp_record):
#   File "/content/drive/My Drive/Colab Notebooks/Advanced-Graphics-AR-and-VR/2019201089-Assignment2/aarect.py", line 52, in hit
# ...

# %%
img = cv2.imread('/content/sample_data/result_3.ppm')
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-47f93ee4b41e> in <module>()
#       1 img = cv2.imread('/content/sample_data/result_3.ppm')
# ----> 2 cv2_imshow(img)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      20       image.
#      21   """
# ---> 22   a = a.clip(0, 255).astype('uint8')
#      23   # cv2 stores colors as BGR; convert to RGB
#      24   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'
