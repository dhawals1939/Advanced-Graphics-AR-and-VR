# %%
# !pip install pyglm
path = '/content/drive/My Drive/Colab Notebooks/Advanced-Graphics-AR-and-VR/2019201089-Assignment2'
import os
from google.colab.patches import cv2_imshow
import cv2
os.chdir(path)

# %%
# !cat problem_1.py

# %%
# !python problem_1.py /content/sample_data/result_1.ppm 200 10

# %%
img = cv2.imread('/content/sample_data/result_1.ppm')
cv2_imshow(img)
