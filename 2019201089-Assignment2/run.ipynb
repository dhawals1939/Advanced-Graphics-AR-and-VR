# %%
# !pip install pyglm
path = '/content/drive/My Drive/Colab Notebooks/Advanced-Graphics-AR-and-VR/2019201089-Assignment2'
import os
from google.colab.patches import cv2_imshow
import cv2
os.chdir(path)

# %%
# !cat cornell_box.py
# Out:
# from hittable_list import hittable_list
# from material import *
# from aarect import *
# from sphere import *
# from texture import *
# import glm
#
#
# def cornell_box() -> hittable_list:
#     checker = checker_texture(glm.vec3(0., 0., 0.), glm.vec3(0.9, 0.9, 0.9))
#     material_ground = metal(.0, tex=checker)
#
#     red = lambertian(glm.vec3(.65, .05, .05))
#     white = lambertian(glm.vec3(.74, .73, .73))
#     green = lambertian(glm.vec3(.12, .45, .15))
#
#     light = diffuse_light(color=glm.vec3(15, 15, 15))
#
#     world = hittable_list(yz_rect(-1, 1, -5, 0, -2, green))  # left wall
#
#     world.add(yz_rect(-1, 1, -5, 0, 2, red))  # right wall
#
#     world.add(xz_rect(-1, 1, -2.5, -1.5, .9, light))  # light
#
#     world.add(xz_rect(-2, 2, -5, 0, -1, material_ground))  # ground
#
#     world.add(xz_rect(-2, 2, -5, 0, 1, white))  # roof
#
#     world.add(xy_rect(-2, 2, -1, 1, -5, white))  # facing wall
#
#     return world

# %%
# !python main.py /content/sample_data/result.ppm 200 10
# Out:
# loading::   4% 8/225 [01:47<48:52, 13.51s/it]Traceback (most recent call last):
#   File "main.py", line 98, in <module>
#     r = cam.get_ray(u, v)
#   File "/content/drive/My Drive/Colab Notebooks/Advanced-Graphics-AR-and-VR/2019201089-Assignment2/camera.py", line 18, in get_ray
#     return ray(self.origin, self.lower_left_corner + u * self.horizontal + v * self.vertical - self.origin)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "main.py", line 101, in <module>
#     write_color(f, color, spp=samples_per_pixel)
# KeyboardInterrupt
# loading::   4% 8/225 [01:48<48:52, 13.51s/it]

# %%
img = cv2.imread('/content/sample_data/result.ppm')
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-95dbe3a9118f> in <module>()
#       1 img = cv2.imread('/content/sample_data/result.ppm')
# ----> 2 cv2_imshow(img)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      20       image.
#      21   """
# ---> 22   a = a.clip(0, 255).astype('uint8')
#      23   # cv2 stores colors as BGR; convert to RGB
#      24   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'

# %%
# !python main.py /content/sample_data/result.ppm 200 10

# %%
# !python main.py /content/sample_data/result.ppm 200 100

# %%
img = cv2.imread('/content/sample_data/result.ppm')
cv2_imshow(img)
