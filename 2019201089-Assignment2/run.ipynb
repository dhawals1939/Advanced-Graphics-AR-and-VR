# %%
# !pip install pyglm
path = '/content/drive/My Drive/Colab Notebooks/Advanced-Graphics-AR-and-VR/2019201089-Assignment2'
import os
from google.colab.patches import cv2_imshow
import cv2
os.chdir(path)
# Out:
# ...
#      |████████████████████████████████| 7.0MB 2.8MB/s
# ...

# %%
# !cat main.py
# Out:
# import math
# import sys
# import time
#
# from tqdm import tqdm
#
# from camera import camera
# from hittable import hit_record, hittable
# from hittable_list import hittable_list
# from ray import ray
# from sphere import sphere
# from util import *
# from material import *
#
#
# def write_color(file, color: glm.vec3, spp=1):
#     if file:
#         r, g, b = color.x, color.y, color.z
#
#         scale = 1 / spp
#         r = glm.sqrt(scale * r)
#         g = glm.sqrt(scale * g)
#         b = glm.sqrt(scale * b)
#
#         file.write('%d %d %d\n' % (256 * clamp(r, 0, .999),
#                                    256 * clamp(g, 0, .999),
#                                    256 * clamp(b, 0, .999)))
#
#
# def ray_color(r: ray, world: hittable, depth: int) -> glm.vec3:
#     rec = hit_record()
#
#     if depth <= 0:
#         return glm.vec3(0, 0, 0)
#
#     if world.hit(r, 0.001, math.inf, rec):
# ...

# %%
# !python main.py result.ppm 30 10
cv2_imshow(cv2.imread('result.ppm'))
# Out:
# loading:: 100% 225/225 [01:51<00:00,  2.01it/s]
# <PIL.Image.Image image mode=RGB size=400x225 at 0x7FD9F4E825F8>

# %%
# !hwinfo
